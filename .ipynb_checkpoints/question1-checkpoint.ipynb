# %% [markdown]
# During this period, seven companies offered scooters. How many scooters did each company have in this time frame? Did the number for each company change over time? Did scooter usage vary by company?

# %%
from sqlalchemy import create_engine, text
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
database_name = 'scooters'

connection_string = f"postgresql://postgres:postgres@localhost:5432/{database_name}"

# %%
engine = create_engine(connection_string)

# %%
query = '''
SELECT DISTINCT companyname AS company,
       COUNT(DISTINCT sumdid) AS scooter_count,
       AVG(tripduration) AS avg_trip_length,
       COUNT(DISTINCT triprecordnum) AS total_trips,
       COUNT(DISTINCT triprecordnum) * 1.0 / COUNT(DISTINCT sumdid) AS avg_trips_per_scooter
FROM trips
WHERE sumdid IN (SELECT sumdid
                 FROM scooters
                 WHERE sumdgroup ILIKE 'Scooter')
    AND tripduration BETWEEN 1 AND 1440
    AND tripdistance > 0
GROUP BY companyname;
'''

with engine.connect() as connection:
    companycounts = pd.read_sql(text(query), con = connection)

# %%
query = '''
SELECT DISTINCT companyname AS company,
       COUNT(DISTINCT sumdid) AS scooter_count,
       AVG(CASE WHEN companyname = 'Bolt Mobility' THEN tripduration/60
                ELSE tripduration END) AS avg_trip_length,
       COUNT(DISTINCT triprecordnum) AS total_trips,
       COUNT(DISTINCT triprecordnum) * 1.0 / COUNT(DISTINCT sumdid) AS avg_trips_per_scooter
FROM trips
WHERE pubtimestamp BETWEEN '2019-05-01 00:01:00.000' AND '2019-05-31 23:59:59.000'
    AND sumdid IN (SELECT sumdid
                   FROM scooters
                   WHERE sumdgroup ILIKE 'Scooter')
    AND tripduration BETWEEN 1 AND 1440
    AND tripdistance > 0
GROUP BY companyname;
'''

with engine.connect() as connection:
    maycounts = pd.read_sql(text(query), con = connection)

# %%
query = '''
SELECT DISTINCT companyname AS company,
       COUNT(DISTINCT sumdid) AS scooter_count,
       AVG(CASE WHEN companyname = 'Bolt Mobility' THEN tripduration/60
                ELSE tripduration END) AS avg_trip_length,
       COUNT(DISTINCT triprecordnum) AS total_trips,
       COUNT(DISTINCT triprecordnum) * 1.0 / COUNT(DISTINCT sumdid) AS avg_trips_per_scooter
FROM trips
WHERE pubtimestamp BETWEEN '2019-06-01 00:01:00.000' AND '2019-06-30 23:59:59.000'
    AND sumdid IN (SELECT sumdid
                   FROM scooters
                   WHERE sumdgroup ILIKE 'Scooter')
    AND tripduration BETWEEN 1 AND 1440
    AND tripdistance > 0
GROUP BY companyname;
'''

with engine.connect() as connection:
    junecounts = pd.read_sql(text(query), con = connection)

# %%
query = '''
SELECT DISTINCT companyname AS company,
       COUNT(DISTINCT sumdid) AS scooter_count,
       AVG(CASE WHEN companyname = 'Bolt Mobility' THEN tripduration/60
                ELSE tripduration END) AS avg_trip_length,
       COUNT(DISTINCT triprecordnum) AS total_trips,
       COUNT(DISTINCT triprecordnum) * 1.0 / COUNT(DISTINCT sumdid) AS avg_trips_per_scooter
FROM trips
WHERE pubtimestamp BETWEEN '2019-07-01 00:01:00.000' AND '2019-07-31 23:59:59.000'
    AND sumdid IN (SELECT sumdid
                   FROM scooters
                   WHERE sumdgroup ILIKE 'Scooter')
    AND tripduration BETWEEN 1 AND 1440
    AND tripdistance > 0
GROUP BY companyname;
'''

with engine.connect() as connection:
    julycounts = pd.read_sql(text(query), con = connection)

# %%
maycounts
# Out:
#          company  scooter_count  avg_trip_length  total_trips  \
# 0           Bird           2849        16.010785         8553
# 1  Bolt Mobility            340        10.834481         1137
# 2         Gotcha            105        10.803707          147
# 3           Lime           1566        16.729623         6920
# 4           Lyft           1359        17.209599         3524
# 5           SPIN            636        21.994539         1577
#
#    avg_trips_per_scooter
# 0               3.002106
# 1               3.344118
# 2               1.400000
# 3               4.418902
# 4               2.593083
# 5               2.479560

# %%
junecounts
# Out:
#          company  scooter_count  avg_trip_length  total_trips  \
# 0           Bird           2701        17.699077         9107
# 1  Bolt Mobility            329        10.716589          881
# 2         Gotcha            133        10.482215          183
# 3           JUMP            172        76.487313          348
# 4           Lime           1406        15.048294        10495
# 5           Lyft           1139        16.770878         2638
# 6           SPIN            669        23.660820         1359
#
#    avg_trips_per_scooter
# 0               3.371714
# 1               2.677812
# 2               1.375940
# 3               2.023256
# 4               7.464438
# 5               2.316067
# 6               2.031390

# %%
julycounts
# Out:
#          company  scooter_count  avg_trip_length  total_trips  \
# 0           Bird           2261        19.319876         6578
# 1  Bolt Mobility            264        11.205884          513
# 2         Gotcha            102         9.302561          183
# 3           JUMP            398        29.198017          388
# 4           Lime            798        15.529330        35953
# 5           Lyft           1009        16.571374         1849
# 6           SPIN            511        21.177008         1196
#
#    avg_trips_per_scooter
# 0               2.909332
# 1               1.943182
# 2               1.794118
# 3               0.974874
# 4              45.053885
# 5               1.832507
# 6               2.340509

# %%
maycounts['month'] = "May"
junecounts['month'] = "June"
julycounts['month'] = "July"

# %%
mjcounts2 = pd.concat([maycounts, junecounts], ignore_index=True)
mjcounts2
# Out:
#           company  scooter_count  avg_trip_length  total_trips  \
# 0            Bird           2849        16.010785         8553
# 1   Bolt Mobility            340        10.834481         1137
# 2          Gotcha            105        10.803707          147
# 3            Lime           1566        16.729623         6920
# 4            Lyft           1359        17.209599         3524
# 5            SPIN            636        21.994539         1577
# 6            Bird           2701        17.699077         9107
# 7   Bolt Mobility            329        10.716589          881
# 8          Gotcha            133        10.482215          183
# 9            JUMP            172        76.487313          348
# 10           Lime           1406        15.048294        10495
# 11           Lyft           1139        16.770878         2638
# 12           SPIN            669        23.660820         1359
#
#     avg_trips_per_scooter month
# 0                3.002106   May
# 1                3.344118   May
# 2                1.400000   May
# 3                4.418902   May
# 4                2.593083   May
# 5                2.479560   May
# 6                3.371714  June
# 7                2.677812  June
# 8                1.375940  June
# 9                2.023256  June
# 10               7.464438  June
# 11               2.316067  June
# 12               2.031390  June

# %%
fullcounts_by_m = pd.concat([mjcounts2, julycounts], ignore_index=True)
fullcounts_by_m
# Out:
#           company  scooter_count  avg_trip_length  total_trips  \
# 0            Bird           2849        16.010785         8553
# 1   Bolt Mobility            340        10.834481         1137
# 2          Gotcha            105        10.803707          147
# 3            Lime           1566        16.729623         6920
# 4            Lyft           1359        17.209599         3524
# 5            SPIN            636        21.994539         1577
# 6            Bird           2701        17.699077         9107
# 7   Bolt Mobility            329        10.716589          881
# 8          Gotcha            133        10.482215          183
# 9            JUMP            172        76.487313          348
# 10           Lime           1406        15.048294        10495
# 11           Lyft           1139        16.770878         2638
# 12           SPIN            669        23.660820         1359
# 13           Bird           2261        19.319876         6578
# 14  Bolt Mobility            264        11.205884          513
# 15         Gotcha            102         9.302561          183
# 16           JUMP            398        29.198017          388
# 17           Lime            798        15.529330        35953
# 18           Lyft           1009        16.571374         1849
# 19           SPIN            511        21.177008         1196
#
#     avg_trips_per_scooter month
# 0                3.002106   May
# 1                3.344118   May
# 2                1.400000   May
# 3                4.418902   May
# 4                2.593083   May
# 5                2.479560   May
# 6                3.371714  June
# 7                2.677812  June
# 8                1.375940  June
# 9                2.023256  June
# 10               7.464438  June
# 11               2.316067  June
# 12               2.031390  June
# 13               2.909332  July
# 14               1.943182  July
# 15               1.794118  July
# 16               0.974874  July
# 17              45.053885  July
# 18               1.832507  July
# 19               2.340509  July

# %%
sns.lineplot(data=fullcounts_by_m, x="month", y="scooter_count", hue="company")

plt.legend()
plt.show()

# %%
companycounts.sort_values("scooter_count", ascending=False)
# Out:
#          company  scooter_count  avg_trip_length  total_trips  \
# 0           Bird           3755        13.687987        10833
# 4           Lime           1751        15.540914        50641
# 5           Lyft           1723        16.006323         3582
# 6           SPIN            754        26.141509         1597
# 3           JUMP            449        33.346155          447
# 1  Bolt Mobility            356      1408.017222         1232
# 2         Gotcha            166        10.196918          187
#
#    avg_trips_per_scooter
# 0               2.884953
# 4              28.921188
# 5               2.078932
# 6               2.118037
# 3               0.995546
# 1               3.460674
# 2               1.126506

# %%
sns.barplot(data=companycounts.sort_values("scooter_count", ascending=False), x="company", y="scooter_count");

# %%
sns.lineplot(data=fullcounts_by_m.groupby(by="month").sum().sort_values("scooter_count", ascending=False), x="month", y="scooter_count")


plt.show()

# %%
lquery = '''
SELECT *
FROM trips
WHERE pubtimestamp BETWEEN '2019-07-01 00:01:00.000' AND '2019-07-31 23:59:59.000'
    AND sumdid IN (SELECT sumdid
                   FROM scooters
                   WHERE sumdgroup ILIKE 'Scooter')
    AND companyname = 'Lime'
    AND tripduration BETWEEN 1 AND 1440
    AND tripdistance > 0;
'''

with engine.connect() as connection:
    julylimes = pd.read_sql(text(lquery), con = connection)

# %%
julylimes.describe()
# Out:
#        tripduration  tripdistance  startlatitude  startlongitude  \
# count  35953.000000  3.595300e+04   35953.000000    35953.000000
# mean      15.529330  6.510834e+03      36.155350      -86.784223
# std       16.651224  2.555233e+04       0.012678        0.012861
# min        1.000000  2.943256e+00      36.037117      -86.879069
# 25%        5.000000  2.068588e+03      36.150439      -86.790097
# 50%       10.000000  4.314949e+03      36.156930      -86.781488
# 75%       19.000000  8.164863e+03      36.162546      -86.776710
# max      131.000000  4.607692e+06      36.299569      -86.548135
#
#         endlatitude  endlongitude
# count  35953.000000  35953.000000
# mean      36.155632    -86.784584
# std        0.019391      0.082496
# min       33.578331   -101.867910
# 25%       36.150732    -86.790349
# 50%       36.157211    -86.781319
# 75%       36.162626    -86.776586
# max       36.231861    -86.548208
